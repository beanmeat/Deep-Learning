# %%
import torch

# %%
x = torch.randn(3, 5)
y = torch.softmax(x, dim=1)
print(x)
print(y)
# Out:
# tensor([[-1.4912, -0.3123,  0.1406,  0.8292,  0.6383],
#         [ 0.2024,  0.9735, -0.9378, -2.0023, -0.5309],
#         [ 0.9496,  1.4989,  0.2070,  0.1878, -0.8316]])
# tensor([[0.0358, 0.1163, 0.1829, 0.3642, 0.3009],
#         [0.2456, 0.5309, 0.0785, 0.0271, 0.1179],
#         [0.2602, 0.4507, 0.1238, 0.1215, 0.0438]])
